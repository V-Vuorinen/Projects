# %%
## Web scraping to CSV file

# %%
import requests
import sqlalchemy
import getpass
import pandas as pd
from bs4 import BeautifulSoup

# %%
# - Define target URL and file path for future use
# - Create counter for loop

url = 'https://en.wikipedia.org/wiki/Fastest_animals'
csv_path = r'C:\Users\vaino\Desktop\Python_jupyter\Fastest_Animals.csv'
df = pd.DataFrame(columns=["Rank", "Animal", "Maximum speed", "Class", "Notes"])

# %%
# - Crate variables to hold credentials for the database connection
# - HINT! password is 12345 :)

table_name = 'fastest_animals'
db_user = 'postgres'
db_password = getpass.getpass("Enter Password")
db_host = 'localhost'
db_port = '5432'
db_name = 'postgres'
# Out:
# Enter Password ········

# %%
##html_page = requests.get(url).text
#data = BeautifulSoup(html_page, 'html.parser')
#tables = data.find_all('tbody')
#rows = tables[0].find_all('tr')

# %%
# - Load the essentials from the webpage

response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')
table = soup.find('table', {'class': 'wikitable'})
rows = table.find_all('tr')[1:]

# %%
# - Create loop to extract the data row by row

for row in rows:
        col = row.find_all('td')
        if len(col) != 0:
            data_dict = {"Rank": col[0].get_text(strip=True),
                         "Animal": col[1].get_text(strip=True),
                         "Maximum Speed": col[2].get_text(strip=True),
                         "Class": col[3].get_text(strip=True),
                         "Notes": col[4].get_text(strip=True)}
            df1 = pd.DataFrame(data_dict, index=[0])
            df = pd.concat([df, df1], ignore_index=True)
        else:
            break

# %%
# - Check if the extraction is successful

df
# Out:
#    Rank                           Animal Maximum speed            Class  \
# 0     1                 Peregrine falcon           NaN    Flight-diving
# 1     2                     Golden eagle           NaN    Flight-diving
# 2     3  White-throated needletail swift           NaN           Flight
# 3     4                   Eurasian hobby           NaN           Flight
# 4     5          Mexican free-tailed bat           NaN           Flight
# 5     6                      Frigatebird           NaN           Flight
# 6     7                Rock dove(pigeon)           NaN           Flight
# 7     8                Spur-winged goose           NaN           Flight
# 8     9                        Gyrfalcon           NaN           Flight
# 9    10            Grey-headed albatross           NaN           Flight
# 10   11                          Cheetah           NaN             Land
# 11   12                         Sailfish           NaN  Flight-swimming
# 12   13               Anna's hummingbird           NaN           Flight
# 13   14                        Swordfish           NaN         Swimming
# 14   15                          Ostrich           NaN             Land
# 15   16                        Pronghorn           NaN             Land
# 16   17                        Springbok           NaN             Land
# 17   18                    Quarter Horse           NaN             Land
# 18   19                  Blue wildebeest           NaN             Land
# 19   20                Thomson's gazelle           NaN             Land
#
#                                                 Notes  \
# 0   The peregrine falcon is the fastest aerial ani...
# 1   Assuming the maximum size at 1.02 m, its relat...
# 2
# 3                      Can sometimes outfly theswift.
# 4   It has been claimed to have the fastest horizo...
# 5   The frigatebird's high speed is helped by its ...
# 6   Pigeons have been clocked flying 92.5 mph (148...
# 7
# 8
# 9
# 10  Fastest land-animal, fastestfeline, the cheeta...
# 11
# 12
# 13
# 14
# 15
# 16
# 17  The American Quarter Horse, or Quarter Horse, ...
# 18
# 19
#
#                                         Maximum Speed
# 0          389 km/h (242 mph)108 m/s (354 ft/s)[1][7]
# 1   240–320 km/h (150–200 mph)67–89 m/s (220–293 f...
# 2                       169 km/h (105 mph)[9][10][11]
# 3                              160 km/h (100 mph)[12]
# 4                              160 km/h (100 mph)[13]
# 5                                   153 km/h (95 mph)
# 6                           148.9 km/h (92.5 mph)[14]
# 7                               142 km/h (88 mph)[15]
# 8                  128 km/h (80 mph)[citation needed]
# 9                   127 km/h (79 mph)[16][17][note 1]
# 10                109.4–120.7 km/h (68.0–75.0 mph)[a]
# 11           109.19 km/h (67.85 mph)[citation needed]
# 12                         98.27 km/h (61.06 mph)[24]
# 13                  97 km/h (60 mph)[citation needed]
# 14                               90 km/h (56 mph)[25]
# 15                            88.5 km/h (55.0 mph)[b]
# 16                           88 km/h (55 mph)[30][31]
# 17                               88.5 km/h (55.0 mph)
# 18                            80.5 km/h (50.0 mph)[c]
# 19                           80.5 km/h (50.0 mph)[35]

# %%
# - Drop the duplicate Maximum speed column

df = df.drop('Maximum speed', axis=1)

# %%
df
# Out:
#    Rank                           Animal            Class  \
# 0     1                 Peregrine falcon    Flight-diving
# 1     2                     Golden eagle    Flight-diving
# 2     3  White-throated needletail swift           Flight
# 3     4                   Eurasian hobby           Flight
# 4     5          Mexican free-tailed bat           Flight
# 5     6                      Frigatebird           Flight
# 6     7                Rock dove(pigeon)           Flight
# 7     8                Spur-winged goose           Flight
# 8     9                        Gyrfalcon           Flight
# 9    10            Grey-headed albatross           Flight
# 10   11                          Cheetah             Land
# 11   12                         Sailfish  Flight-swimming
# 12   13               Anna's hummingbird           Flight
# 13   14                        Swordfish         Swimming
# 14   15                          Ostrich             Land
# 15   16                        Pronghorn             Land
# 16   17                        Springbok             Land
# 17   18                    Quarter Horse             Land
# 18   19                  Blue wildebeest             Land
# 19   20                Thomson's gazelle             Land
#
#                                                 Notes  \
# 0   The peregrine falcon is the fastest aerial ani...
# 1   Assuming the maximum size at 1.02 m, its relat...
# 2
# 3                      Can sometimes outfly theswift.
# 4   It has been claimed to have the fastest horizo...
# 5   The frigatebird's high speed is helped by its ...
# 6   Pigeons have been clocked flying 92.5 mph (148...
# 7
# 8
# 9
# 10  Fastest land-animal, fastestfeline, the cheeta...
# 11
# 12
# 13
# 14
# 15
# 16
# 17  The American Quarter Horse, or Quarter Horse, ...
# 18
# 19
#
#                                         Maximum Speed
# 0          389 km/h (242 mph)108 m/s (354 ft/s)[1][7]
# 1   240–320 km/h (150–200 mph)67–89 m/s (220–293 f...
# 2                       169 km/h (105 mph)[9][10][11]
# 3                              160 km/h (100 mph)[12]
# 4                              160 km/h (100 mph)[13]
# 5                                   153 km/h (95 mph)
# 6                           148.9 km/h (92.5 mph)[14]
# 7                               142 km/h (88 mph)[15]
# 8                  128 km/h (80 mph)[citation needed]
# 9                   127 km/h (79 mph)[16][17][note 1]
# 10                109.4–120.7 km/h (68.0–75.0 mph)[a]
# 11           109.19 km/h (67.85 mph)[citation needed]
# 12                         98.27 km/h (61.06 mph)[24]
# 13                  97 km/h (60 mph)[citation needed]
# 14                               90 km/h (56 mph)[25]
# 15                            88.5 km/h (55.0 mph)[b]
# 16                           88 km/h (55 mph)[30][31]
# 17                               88.5 km/h (55.0 mph)
# 18                            80.5 km/h (50.0 mph)[c]
# 19                           80.5 km/h (50.0 mph)[35]

# %%
# - We will only be interested in the Maximum Speed in km/h

df["Maximum Speed"] = df["Maximum Speed"].str.split().str[:2]

# %%
# - Use lambda function to format the Maximum Speed values

df['Maximum Speed'] = df['Maximum Speed'].apply(lambda x: [x[0].replace('[', ''), x[1].replace(']', '')])
df['Maximum Speed'] = df['Maximum Speed'].apply(lambda x: ' '.join(x))

# %%
df
# Out:
#    Rank                           Animal            Class  \
# 0     1                 Peregrine falcon    Flight-diving
# 1     2                     Golden eagle    Flight-diving
# 2     3  White-throated needletail swift           Flight
# 3     4                   Eurasian hobby           Flight
# 4     5          Mexican free-tailed bat           Flight
# 5     6                      Frigatebird           Flight
# 6     7                Rock dove(pigeon)           Flight
# 7     8                Spur-winged goose           Flight
# 8     9                        Gyrfalcon           Flight
# 9    10            Grey-headed albatross           Flight
# 10   11                          Cheetah             Land
# 11   12                         Sailfish  Flight-swimming
# 12   13               Anna's hummingbird           Flight
# 13   14                        Swordfish         Swimming
# 14   15                          Ostrich             Land
# 15   16                        Pronghorn             Land
# 16   17                        Springbok             Land
# 17   18                    Quarter Horse             Land
# 18   19                  Blue wildebeest             Land
# 19   20                Thomson's gazelle             Land
#
#                                                 Notes     Maximum Speed
# 0   The peregrine falcon is the fastest aerial ani...          389 km/h
# 1   Assuming the maximum size at 1.02 m, its relat...      240–320 km/h
# 2                                                              169 km/h
# 3                      Can sometimes outfly theswift.          160 km/h
# 4   It has been claimed to have the fastest horizo...          160 km/h
# 5   The frigatebird's high speed is helped by its ...          153 km/h
# 6   Pigeons have been clocked flying 92.5 mph (148...        148.9 km/h
# 7                                                              142 km/h
# 8                                                              128 km/h
# 9                                                              127 km/h
# 10  Fastest land-animal, fastestfeline, the cheeta...  109.4–120.7 km/h
# 11                                                          109.19 km/h
# 12                                                           98.27 km/h
# 13                                                              97 km/h
# 14                                                              90 km/h
# 15                                                            88.5 km/h
# 16                                                              88 km/h
# 17  The American Quarter Horse, or Quarter Horse, ...         88.5 km/h
# 18                                                            80.5 km/h
# 19                                                            80.5 km/h

# %%
# - Create engine for database connection
# - Use the credentials created earlier and remember to dispose the engine

credentials = f'postgresql://{db_user}:{db_password}@{db_host}:{db_port}/{db_name}'
engine = sqlalchemy.create_engine(credentials)

df.to_sql(table_name, engine, if_exists='replace', index=False)

engine.dispose()

# %%
# - Write dataframe into CSV file

df.to_csv(csv_path)
